# %% [markdown]
# # Dataset Inspection
# Inspect train/valid/eval JSONL files generated by the local safety dataset scripts.

# %%
from pathlib import Path
import json

root = Path.cwd()
train_path = root / 'data/processed/train.jsonl'
rows = [json.loads(line) for line in train_path.read_text(encoding='utf-8').splitlines() if line.strip()]
len(rows), rows[0]['messages'][0]['role'] if rows else None
