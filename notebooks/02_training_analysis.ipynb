# %% [markdown]
# # Training Analysis
# Review loss history and eval metrics logged during LoRA training.

# %%
from pathlib import Path
import json

root = Path.cwd()
loss_history = json.loads((root / 'logs/train/loss_history.json').read_text(encoding='utf-8'))
eval_metrics = json.loads((root / 'logs/train/eval_during_train.json').read_text(encoding='utf-8'))
loss_history[:3], eval_metrics
